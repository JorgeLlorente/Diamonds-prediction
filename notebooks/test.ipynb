# %%
import pandas as pd
import numpy as np
import math

import matplotlib.pyplot as plt
from matplotlib import style
import matplotlib.ticker as ticker
import seaborn as sns

from sklearn.preprocessing import MinMaxScaler
from sklearn.preprocessing import StandardScaler
from sklearn.preprocessing import LabelEncoder 
from sklearn.preprocessing import OneHotEncoder  
from sklearn.preprocessing import OrdinalEncoder



plt.rcParams["figure.figsize"] = (10,8)

import warnings
warnings.filterwarnings('ignore')

import sys
sys.path.append("../")

import src.support as sp

# %%
df = pd.read_csv("../data/test.csv")

# %%
df.head()
# Out:
#    id  carat      cut color clarity  depth  table     x     y     z
# 0   0   0.32    Ideal     I     SI1   60.5   58.0  4.43  4.49  2.70
# 1   1   1.24  Premium     I     SI1   62.9   60.0  6.80  6.74  4.26
# 2   2   1.66  Premium     D     SI1   62.0   59.0  7.55  7.60  4.70
# 3   3   0.75  Premium     D     SI2   60.6   56.0  5.94  5.90  3.59
# 4   4   1.50     Fair     E     SI2   64.8   55.0  7.26  7.15  4.67

# %%
scaler = StandardScaler()

# %%
df_numericas = df.select_dtypes(include=np.number)

# %%
df_numericas.drop(["id", "depth","table"], axis=1, inplace=True)

# %%
num_col = df_numericas.columns

# %%
scaler.fit(df[num_col])
# Out:
# StandardScaler()

# %%
X_escaladas = scaler.transform(df[num_col])
X_escaladas
# Out:
# array([[-1.02318382, -1.17630537, -1.13248052, -1.22240722],
#        [ 0.94188032,  0.95647748,  0.90693781,  1.04001212],
#        [ 1.83897482,  1.63140876,  1.68644882,  1.6781304 ],
#        ...,
#        [-1.0659026 , -1.29329346, -1.28656991, -1.2514126 ],
#        [ 0.96323971,  1.14545823,  1.22418066,  0.95299599],
#        [ 0.02342643,  0.20055444,  0.16368313,  0.16985084]])

# %%
df2 = df.copy()

# %%
df2[num_col] = X_escaladas
df2.head()
# Out:
#    id     carat      cut color clarity  depth  table         x         y  \
# 0   0 -1.023184    Ideal     I     SI1   60.5   58.0 -1.176305 -1.132481
# 1   1  0.941880  Premium     I     SI1   62.9   60.0  0.956477  0.906938
# 2   2  1.838975  Premium     D     SI1   62.0   59.0  1.631409  1.686449
# 3   3 -0.104730  Premium     D     SI2   60.6   56.0  0.182556  0.145555
# 4   4  1.497225     Fair     E     SI2   64.8   55.0  1.370435  1.278565
#
#           z
# 0 -1.222407
# 1  1.040012
# 2  1.678130
# 3  0.068332
# 4  1.634622

# %%
df2.drop(["id", "depth","table"], axis=1, inplace=True)

# %%
df2.head()
# Out:
#       carat      cut color clarity         x         y         z
# 0 -1.023184    Ideal     I     SI1 -1.176305 -1.132481 -1.222407
# 1  0.941880  Premium     I     SI1  0.956477  0.906938  1.040012
# 2  1.838975  Premium     D     SI1  1.631409  1.686449  1.678130
# 3 -0.104730  Premium     D     SI2  0.182556  0.145555  0.068332
# 4  1.497225     Fair     E     SI2  1.370435  1.278565  1.634622

# %%
columnas_cat = df2.select_dtypes(include = ["object", "category"]).columns

# %%
sp.label_encoder(df2, columnas_cat)
# Out:
#           carat        cut color clarity         x         y         z  \
# 0     -1.023184      Ideal     I     SI1 -1.176305 -1.132481 -1.222407
# 1      0.941880    Premium     I     SI1  0.956477  0.906938  1.040012
# 2      1.838975    Premium     D     SI1  1.631409  1.686449  1.678130
# 3     -0.104730    Premium     D     SI2  0.182556  0.145555  0.068332
# 4      1.497225       Fair     E     SI2  1.370435  1.278565  1.634622
# ...         ...        ...   ...     ...       ...       ...       ...
# 13480  0.642849    Premium     G     SI1  0.902483  0.870681  0.662942
# 13481  0.215661  Very Good     D     SI1  0.362538  0.417477  0.416397
# 13482 -1.065903      Ideal     F     VS2 -1.293293 -1.286570 -1.251413
# 13483  0.963240      Ideal     I     SI1  1.145458  1.224181  0.952996
# 13484  0.023426    Premium     F     SI1  0.200554  0.163683  0.169851
#
#        cut_encoded  color_encoded  clarity_encoded
# 0                2              5                2
# ...

# %%
df2.drop(["cut", "color", "clarity"], axis=1, inplace=True)

# %%
df2.to_csv("../data/test_prep.csv")
